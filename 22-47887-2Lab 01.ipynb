# %% [markdown]
# # About this notebook
# <p style="text-align: justify"> Here, you will learn the basic coding and data structures including numbers, strings, list, dictionaries and more. Some codes already done for demonstration. Some other codes, you will do as excercises.</p>
#
# ## Submission
# <p style="text-align: justify">After completing the practice codes and exercises, download the notebook (.pynb file) and submit the notebook  to MS Teams inbox in the class period.</p>
# <p> 1.<b> You must submit your own code</b>. If similarity found negative marking will be given.</p>
#
# <p> 2. Other file format (except .pynb) or link will not be accepted.</p>

# %% [markdown]
# # Number

# %% [markdown]
# **Basic Arithmetic Operations**

# %%
# Addition, Subtraction, Multiplication, Division
a = 10
b = 5

sum_result = a + b
difference_result = a - b
product_result = a * b
division_result = a / b

print(f"Sum: {sum_result}, Difference: {difference_result}, Product: {product_result}, Division: {division_result}")
# Out:
# Sum: 15, Difference: 5, Product: 50, Division: 2.0

# %%
# Addition, Subtraction, Multiplication, Division
x = 65
y = 10

sum_result = x + y
difference_result = x- y
product_result = x* y
division_result = x/ y

print(f"Sum: {sum_result}, Difference: {difference_result}, Product: {product_result}, Division: {division_result}")
# Out:
# Sum: 75, Difference: 55, Product: 650, Division: 6.5

# %% [markdown]
# **Exponentiation and Modulus**

# %%
# Exponentiation (Power) and Modulus (Remainder)
base = 2
exponent = 3

power_result = base ** exponent
modulus_result = a % b

print(f"Power: {power_result}, Modulus: {modulus_result}")
# Out:
# Power: 8, Modulus: 0

# %%
# Exponentiation (Power) and Modules (REmainder)
base1 =4
exponent1=8
power_result = base1 ** exponent1
modulus_result = x % y

print(f"Power: {power_result}, Modulus: {modulus_result}")
# Out:
# Power: 65536, Modulus: 0

# %% [markdown]
# **Floor Division**

# %%
# Floor Division
floor_result = a // b  # floored division result

print(f"Floor Division: {floor_result}")
# Out:
# Floor Division: 2

# %%
# Floor Division
floor_result1 = x// y   # floored division result

print(f"Floor Division: {floor_result}")
# Out:
# Floor Division: 2

# %% [markdown]
# **Absolute Value and Rounding**

# %%
# Absolute Value and Rounding
negative_number = -7.5

absolute_value = abs(negative_number)
rounded_value = round(negative_number)

print(f"Absolute Value: {absolute_value}, Rounded Value: {rounded_value}")
# Out:
# Absolute Value: 7.5, Rounded Value: -8

# %%
 #Absolute Value and Rounding
negative_number1 = -8.3

absolute_value1 = abs(negative_number1)
rounded_value1 = round(negative_number1)

print(f"Absolute Value: {absolute_value1}, Rounded Value: {rounded_value1}")
# Out:
# Absolute Value: 8.3, Rounded Value: -8

# %% [markdown]
# **Using the math module for advanced number operations**

# %%
import math

# Square root, Factorial, and Trigonometric functions
square_root = math.sqrt(16)
factorial_result = math.factorial(5)
sin_value = math.sin(math.radians(30))

print(f"Square Root: {square_root}, Factorial: {factorial_result}, sin(30 degrees): {sin_value}")
# Out:
# Square Root: 4.0, Factorial: 120, sin(30 degrees): 0.49999999999999994

# %% [markdown]
# **Random Number Generation**

# %%
import math
 #Square root , Factorial , and Trigonometric Funtions
 square_root = math.sqrt(16)
 factorial_root=math.factorial(3)
 sin_value1 = math.sin(math.radians(90))

print(f"Square Root: {square_root1}, Factorial: {factorial_root}, sin(90 degrees): {sin_value1}")
# Out:
#   File "/tmp/ipython-input-29-1653986170.py", line 3
#     square_root = math.sqrt(16)
#     ^
# IndentationError: unexpected indent

# %%
import random

# Generate a random number between 1 and 100
random_number = random.randint(1, 100)
print(f"Random Number: {random_number}")

# Generate a random float between 0 and 1
random_float = random.random()
print(f"Random Float: {random_float}")
# Out:
# Random Number: 23
# Random Float: 0.7349171668763614

# %%
import random

# Generate a random number between 1 and 80
random_number1 = random.randint(1, 80)
print(f"Random Number: {random_number1}")

# Generate a random float between 0 and 1
random_float = random.random()
print(f"Random Float: {random_float}")
# Out:
# Random Number: 12
# Random Float: 0.9995714766697741

# %% [markdown]
# <b>Note:</b> A cell in Python will only display the value of the last expression. If you want to output other values, you should use the *print()* function.

# %% [markdown]
# # Object types
# The basic object types are Numbers, Strings, Lists, Dictionaries, Tuples, Files and Other types (Sets, types, None, Booleans etc.)

# %% [markdown]
# **Integer and Float**

# %%
a=10.5
b=6

# %%
# Checking the type of an object
print(type(a))
print(type(b))
# Out:
# <class 'float'>
# <class 'int'>

# %%
# Checking the type of an object
print(type(v))
print(type(s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-32-1818424334.py in <cell line: 0>()
#       1 # Checking the type of an object
# ----> 2 print(type(v))
#       3 print(type(s))
#
# NameError: name 'v' is not defined

# %% [markdown]
# **String**

# %%
# Concatenation
greeting = "Hello, "
name = "Alice"
message = greeting + name  # Combine strings
print(message)
# Out:
# Hello, Alice

# %%
# Concatenation
greeting = "Hi, "
name = "ADib"
message = greeting + name  # Combine strings
print(message)
# Out:
# Hi, ADib

# %%
# Repetition
repeat_string = "Hi! " * 3
print(repeat_string)
# Out:
# Hi! Hi! Hi!

# %%
# Repetition
repeat_string = "yo! " * 3
print(repeat_string)
# Out:
# yo! yo! yo!

# %%
# Slicing
text = "Hello, World!"
substring = text[7:12]  # Extract substring
print(substring)
# Out:
# World

# %%
# Slicing
text = "hi nice, World!"
substring = text[2:125]  # Extract substring
print(substring)
# Out:
#  nice, World!

# %%
# Changing case
text = "hello"
upper_case = text.upper()  # Convert to uppercase
lower_case = text.lower()  # Convert to lowercase
print(upper_case)
print(lower_case)
# Out:
# HELLO
# hello

# %%
# Changing case
text = "PsYCholoGy"
upper_case = text.upper()  # Convert to uppercase
lower_case = text.lower()  # Convert to lowercase
print(upper_case)
print(lower_case)
# Out:
# PSYCHOLOGY
# psychology

# %%
# Stripping whitespace
text = "   Hello, World!   "
stripped_text = text.strip()  # Removes spaces from both ends
print(stripped_text)
# Out:
# Hello, World!

# %%
# Stripping whitespace
text = "   Hi, Sir!   "
stripped_text = text.strip()  # Removes spaces from both ends
print(stripped_text)
# Out:
# Hi, Sir!

# %%
# Finding substring
text = "Hello, World!"
index = text.find("World")  # Returns the index where "substring" starts
print(index)
# Out:
# 7

# %%
# Replacing substring
text = "welcome, World!"
new_text = text.replace("World", "sir")
print(new_text)
# Out:
# welcome, sir!

# %%
# Replacing substring
text = "Hello, World!"
new_text = text.replace("World", "Python")
print(new_text)

# %%
# Checking substring existence
text = "Hello, World!"
contains_hello = "Hello" in text
contains_python = "Python" in text
print(contains_hello)
print(contains_python)
# Out:
# True
# False

# %%
# Checking substring existence
text = "Big, Boss!"
contains_hello = "Hello" in text
contains_python = "Boss" in text
print(contains_hello)
print(contains_python)
# Out:
# False
# True

# %%
# String length
text = "Hello, World!"
length = len(text)
print(length)
# Out:
# 13

# %%
# String length
text = "Hello, AIUBIAN!"
length = len(text)
print(length)
# Out:
# 15

# %%
# Splitting string
text = "apple,banana,orange"
fruits = text.split(",")  # Split by comma
print(fruits)
# Out:
# ['apple', 'banana', 'orange']

# %%
# Splitting string
text = "red,black,blue"
fruits = text.split(",")  # Split by comma
print(fruits)
# Out:
# ['red', 'black', 'blue']

# %%
# Joining strings
fruits = ['apple', 'banana', 'orange']
joined_fruits = ", ".join(fruits)
print(joined_fruits)
# Out:
# apple, banana, orange

# %%
# Joining strings
fruits = ['black', 'red', 'yellow']
joined_colour = ", ".join(colour)
print(joined_colour)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-48-4271414950.py in <cell line: 0>()
#       1 # Joining strings
#       2 fruits = ['black', 'red', 'yellow']
# ----> 3 joined_colour = ", ".join(colour)
#       4 print(joined_colour)
#
# NameError: name 'colour' is not defined

# %%
# String formatting
name = "Alice"
age = 25
formatted_string = f"My name is {name} and I am {age} years old."
print(formatted_string)
# Out:
# My name is Alice and I am 25 years old.

# %%
# String formatting
name = "Aliv"
age = 18
formatted_string = f"My name is {name} and I am {age} years old. got it ?"
print(formatted_string)
# Out:
# My name is Aliv and I am 18 years old. got it ?

# %%
# Checking start or end
text = "Hello, World!"
starts_with_hello = text.startswith("Hello")
ends_with_world = text.endswith("World!")
print(starts_with_hello)
print(ends_with_world)
# Out:
# True
# True

# %%
# Checking start or end
text = "Excilent , Work!"
starts_with_hello = text.startswith("Hello")
ends_with_world = text.endswith("Work !")
print(starts_with_hello)
print(ends_with_work)
# Out:
# False
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-51-1581017194.py in <cell line: 0>()
#       4 ends_with_world = text.endswith("Work !")
#       5 print(starts_with_hello)
# ----> 6 print(ends_with_work)
#
# NameError: name 'ends_with_work' is not defined

# %%
# Counting occurrences
text = "banana"
count_a = text.count("a")
print(count_a)
# Out:
# 3

# %%
# Counting occurrences
text = "bananaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA"
count_a = text.count("a")
print(count_a)
# Out:
# 33

# %%
# Checking if alphabetic
text = "Hello"
is_alpha = text.isalpha()
print(is_alpha)

text = "Hello123"
is_alpha = text.isalpha()
print(is_alpha)
# Out:
# True
# False

# %%
# Checking if alphabetic
text1 = "Hello"
is_alpha = text1.isalpha()
print(is_alpha)

text1 = "Hello123"
is_alpha = text.isalpha()
print(is_alpha)
# Out:
# True
# False

# %%
# Checking if alphabetic
text = "Hello"
is_alpha = text.isalpha()
print(is_alpha)

text = "Hello123"
is_alpha = text.isalpha()
print(is_alpha)
# Out:
# True
# False

# %%
# Negative index example
text = "Hello, World!"
last_char = text[-1:]  # Last character
print(last_char)
# Out:
# !

# %%
# Negative index example
text = "Hi, Aiunian"
last_char = text[-1:]  # Last character
print(last_char)
# Out:
# n

# %%
# Negative index slicing
substring = text[-6:-1]
print(substring)
# Out:
# iunia

# %%
# Reversing string
reversed_text = text[::-1]  # Reverse the entire string
print(reversed_text)
# Out:
# nainuiA ,iH

# %%
# Slicing with negative step
reversed_substring = text[-7:-1:2]  # Start from index -7, stop at index -1, step by 2
print(reversed_substring)
# Out:
# Aui

# %% [markdown]
# **List**

# %%
# Creating a list
fruits = ["apple", "banana", "cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# Creating a list
count = ["one ", "two", "six"]
print(count)
# Out:
# ['one ', 'two', 'six']

# %%
# Accessing list elements
first_fruits = fruits[0]
print(first_fruit)

last_fruit = fruits[-1]  # Last element
print(last_fruit)
# Out:
# apple
# cherry

# %% [markdown]
# Like strings (and all other built-in sequence types), lists can be indexed and sliced:

# %%
# Accessing list elements
first_count = count[0]
print(first_count)

last_fruit = count[-1]  # Last element
print(last_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-66-1094288701.py in <cell line: 0>()
#       1 # Accessing list elements
# ----> 2 first_count = count[0]
#       3 print(first_count)
#       4
#       5 last_fruit = count[-1]  # Last element
#
# NameError: name 'count' is not defined

# %%
# Slicing a list
sublist = fruits[1:3]  # Elements from index 1 to 2
print(sublist)
# Out:
# ['banana', 'cherry']

# %%
# Appending an element
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
# Inserting an element
fruits.insert(1, "grape")  # Insert "grape" at index 1
print(fruits)
# Out:
# ['apple', 'grape', 'banana', 'cherry', 'orange']

# %%
# Removing by value
fruits.remove("banana")
print(fruits)

# Removing by index
removed_fruit = fruits.pop(2)  # Removes element at index 2
print(removed_fruit)
print(fruits)
# Out:
# ['apple', 'grape', 'cherry', 'orange']
# cherry
# ['apple', 'grape', 'orange']

# %%
# Finding the index of an element
index_of_grape = fruits.index("grape")
print(index_of_grape)
# Out:
# 1

# %%
# Checking existence of an element
exists = "apple" in fruits
print(exists)

exists = "banana" in fruits
print(exists)
# Out:
# True
# False

# %%
# Getting the length of the list
length = len(fruits)
print(length)
# Out:
# 3

# %%
# Sorting a list
fruits = ["orange", "banana", "apple", "grape"]
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
# Reversing a list
fruits.reverse()
print(fruits)
# Out:
# ['orange', 'grape', 'banana', 'apple']

# %%
# List comprehension
numbers = [1, 2, 3, 4, 5]
squared_numbers = [n ** 2 for n in numbers]
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25]

# %%
# Extending a list
more_fruits = ["kiwi", "melon"]
fruits.extend(more_fruits)
print(fruits)
# Out:
# ['orange', 'grape', 'banana', 'apple', 'kiwi', 'melon']

# %%
# List with different data types in nested lists
mixed_nested_list = [[1, "apple", 3.14], [True, "banana", None], [False, 42, "hello"]]

# Accessing elements
print(mixed_nested_list[0])
print(mixed_nested_list[1][1])
print(mixed_nested_list[2][2])

# Modifying an element in the nested list
mixed_nested_list[2][0] = True
print(mixed_nested_list)
# Out:
# [1, 'apple', 3.14]
# banana
# hello
# [[1, 'apple', 3.14], [True, 'banana', None], [True, 42, 'hello']]

# %% [markdown]
# Lists also support operations like concatenation

# %%
# Two lists to concatenate
list1 = [1, 2, 3]
list2 = [4, 5, 6]

# Concatenating the lists
result = list1 + list2
print(result)  # Output: [1, 2, 3, 4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# **Dictionary**
# <p style="text-align: justify">Dictionaries are sometimes found in other languages as “associative memories” or “associative arrays”. Unlike sequences, which are indexed by a range of numbers, dictionaries are indexed by keys, which can be any immutable type; strings and numbers can always be keys.</p>
#
# <p style="text-align: justify">It is best to think of a dictionary as a set of key: value pairs, with the requirement that the keys are unique (within one dictionary). A pair of braces creates an empty dictionary: {}. Placing a comma-separated list of key:value pairs within the braces adds initial key:value pairs to the dictionary; this is also the way dictionaries are written on output.</p>

# %%
# Using curly braces
person = {"name": "John", "age": 25, "city": "New York"}

# Using dict() constructor
person2 = dict(name="Jane", age=30, city="Los Angeles")

print(person)
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
# Accessing a value using a key
print(person["name"])
print(person2["age"])

# Using get() method (safe way to access values)
print(person.get("city"))
print(person.get("country", "Not found"))
# Out:
# John
# 30
# New York
# Not found

# %%
# Adding a new key-value pair
person["country"] = "USA"
print(person)

# Updating an existing key-value pair
person["age"] = 26
print(person)
# Out:
# {'name': 'John', 'age': 26, 'city': 'New York', 'country': 'USA'}
# {'name': 'John', 'age': 26, 'city': 'New York', 'country': 'USA'}

# %%
# Using del to remove a key-value pair
del person["city"]
print(person)

# Using pop() to remove a key-value pair and get the value
age = person.pop("age")
print(person)
print(age)

# Using popitem() to remove and return the last key-value pair
last_item = person.popitem()
print(person)
print(last_item)
# Out:
# {'name': 'John', 'age': 26, 'country': 'USA'}
# {'name': 'John', 'country': 'USA'}
# 26
# {'name': 'John'}
# ('country', 'USA')

# %%
# Checking if a key exists
print("name" in person)
print("age" in person)
# Out:
# True
# False

# %%
# Iterating over keys
for key in person:
    print(key)

# Iterating over values
for value in person.values():
    print(value)

# Iterating over key-value pairs
for key, value in person.items():
    print(key, value)
# Out:
# name
# John
# name John

# %% [markdown]
# **Tuples and Sets**
# <br>Use the content from [here](https://docs.python.org/3/tutorial/datastructures.html#tuples-and-sequences) to follow some examples on tuple and set.

# %%
# Iterating over keys
for key in person:
    print(key)

# Iterating over values
for value in person.values():
    print(value)

# Iterating over key-value pairs
for key, value in person.items():
    print(key, value)
# Out:
# name
# John
# name John

# %%
# code from here

# %% [markdown]
# <b> Exercise 1:</b> Implement stack using list
# <p><b>Hints:</b> The list methods make it very easy to use a list as a stack, where the last element added is the first element retrieved (“last-in, first-out”). To add an item to the top of the stack, use append(). To retrieve an item from the top of the stack, use pop() without an explicit index</p>

# %%
#CODEclass Stack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if not self.is_empty():
            return self.stack.pop()
        else:
            return None   # or raise an exception

    def peek(self):
        if not self.is_empty():
            return self.stack[-1]
        else:
            return None

    def is_empty(self):
        return len(self.stack) == 0

    def size(self):
        return len(self.stack)

# Example usage:
s = Stack()
s.push(10)
s.push(20)
s.push(30)

print(s.pop())      # Output: 30
print(s.peek())     # Output: 20
print(s.is_empty()) # Output: False
print(s.size())     # Output: 2
# Out:
#   File "/tmp/ipython-input-63-2147571805.py", line 2
#     def __init__(self):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# <b> Exercise 2:</b> Implement queue using list
# <p><b>Hints:</b> It is also possible to use a list as a queue, where the first element added is the first element retrieved (“first-in, first-out”)</p>

# %%
#CODEclass Queue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.queue.pop(0)   # remove from the front
        else:
            return None   # or raise an exception

    def peek(self):
        if not self.is_empty():
            return self.queue[0]
        else:
            return None

    def is_empty(self):
        return len(self.queue) == 0

    def size(self):
        return len(self.queue)

# Example usage:
q = Queue()
q.enqueue(10)
q.enqueue(20)
q.enqueue(30)

print(q.dequeue())    # Output: 10
print(q.peek())       # Output: 20
print(q.is_empty())   # Output: False
print(q.size())       # Output: 2

# %% [markdown]
# <b> Exercise 3:</b> Define a dictionary to store the details of 3 persons. Also, print some data from the dictionary.
#  <p><b>Hint:</b> You may require nesting dictionary, lists, string inside the dictionary.</p>

# %%
# Define dictionary with details of 3 persons
people = {
    "person1": {
        "name": "Alice",
        "age": 25,
        "email": "alice@example.com",
        "hobbies": ["reading", "traveling"]
    },
    "person2": {
        "name": "Bob",
        "age": 30,
        "email": "bob@example.com",
        "hobbies": ["cycling", "gaming"]
    },
    "person3": {
        "name": "Charlie",
        "age": 28,
        "email": "charlie@example.com",
        "hobbies": ["painting", "swimming"]
# Out:
#   File "/tmp/ipython-input-64-4223600122.py", line 19
#     "hobbies": ["painting", "swimming"]
#                                        ^
# SyntaxError: incomplete input

# %% [markdown]
# # You may add more examples by yourself below

# %%
#CODE
